# %%
import numpy as np
import pandas as pd
import re

data = pd.read_csv('legislators.csv')

# %%
'''
namestring is of the form firstname#lastname#state

firstname doesn't matter
'''
def reference_leg_id(namestring):
    if type(namestring) == str:
        namestring = namestring.encode('utf-8')
        locs = [m.start() for m in re.finditer('#', namestring)]
        lastname = ""
        state = ""
        for i in range(0,len(locs)):
            if i == 0:
                lastname = namestring[locs[i]+1:locs[i+1]]
            else:
                state = namestring[locs[i]+1:]
                
        if lastname == 'St Germain':
            lastname = 'St. Germain'
        if lastname == 'Waggoner' and state == 'LA':
            return "unknown"
        if lastname == 'Roth Jr.' and state == 'DE':
            lastname = 'Roth'
        if lastname == 'Lambert' and state == 'AR':
            lastname = 'Lincoln'
        if lastname == 'Jackson-Lee' and state == 'TX':
            lastname = 'Jackson Lee'
        

        return data.vote_id[data.last_name == lastname][data.state == state].iloc[0]
    else:
        return "unknown"

# %%
s113 = pd.read_csv('cleanedcsv/111senate.csv')

for index,row in s113.iterrows():
    print reference_leg_id(row.sponsor)
# Out:
# S167
# S299
# S182
# S182
# P000034
# P000034
# P000034
# P000034
# P000034
# P000034
# P000034
# P000034
# P000034
# P000034
# P000034
# P000034
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# S210
# S210
# S210
# S210
# S210
# S210
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# O000007
# H001032
# M000310
# M000310
# M000310
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S201
# S057
# S057
# S057
# S057
# S201
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# S131
# M000087
# M000087
# M000087
# O000007
# S131
# O000007
# O000007
# O000007
# O000007
# W000215
# W000215
# O000007
# W000797
# W000797
# P000523
# P000523
# P000523
# P000523
# P000523
# P000523
# P000523
# P000523
# P000523
# P000523
# P000523
# S131
# S131
# S131
# S131
# S131
# S131
# S131
# S131
# S131
# S131
# S131
# P000099
# P000099
# P000099
# P000099
# P000099
# R000053
# R000053
# R000053
# R000053
# D000216
# D000216
# D000216
# D000216
# O000007
# O000007
# O000007
# S222
# O000085
# O000085
# O000085
# O000085
# O000085
# O000085
# O000085
# O000085
# O000085
# O000085
# D000327
# D000327
# D000327
# D000327
# W000797
# M001120
# M001120
# M001120
# M001120
# M001120
# M001120
# M001120
# M001120
# M001120
# M001120
# M001120
# M000845
# D000216
# P000099
# P000523
# S000465
# D000327
# M000404
# M000845
# M000845
# E000063
# E000063
# E000063
# S213
# S213
# R000053
# R000053
# R000053
# R000053
# R000053
# R000053
# R000053
# R000053
# R000053
# R000053
# R000053
# O000085
# R000053
# R000053
# R000053
# M001120
# R000053
# R000053
# R000053
# R000053
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# M000845
# B000754
# R000053
# R000053
# R000053
# R000053
# R000053
# M000845
# R000053
# R000053
# S000749
# P000593
# S131
# S131
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# D000390
# F000339
# O000007
# O000007
# O000007
# O000007
# O000007
# R000053
# R000053
# R000053
# R000053
# R000053
# R000053
# B000410
# F000339
# R000053
# C000945
# S172
# R000053
# F000339
# L000480
# L000480
# L000480
# A000363
# S253
# O000006
# A000362
# unknown
# unknown
# unknown
# unknown
# unknown
# E000063
# unknown
# unknown
# unknown
# unknown

# %%
namestring = 'Sheila#Jackson-Lee#TX'
namestring = namestring.encode('utf-8')
locs = [m.start() for m in re.finditer('#', namestring)]
lastname = ""
state = ""
for i in range(0,len(locs)):
    if i == 0:
        lastname = namestring[locs[i]+1:locs[i+1]]
    else:
        state = namestring[locs[i]+1:]
        
print lastname
print state

print data.vote_id[data.last_name == lastname][data.state == state]
# Out:
# Jackson-Lee
# TX
# Series([], Name: vote_id, dtype: object)

# %%
test = pd.read_csv('cleanedcsv/113senate.csv')

for i in range(0, len(test.sponsor)):
    print test.sponsor[i]
    print reference_leg_id(test.sponsor[i])

# test.to_csv('test.csv', index=False)
# Out:
# Harry#Reid#NV
# S198
# Harry#Reid#NV
# S198
# Harold#Rogers#KY
# R000395
# Harold#Rogers#KY
# R000395
# Dave#Camp#MI
# C000071
# Patrick J.#Leahy#VT
# S057
# Patrick J.#Leahy#VT
# S057
# Patrick J.#Leahy#VT
# S057
# Patrick J.#Leahy#VT
# S057
# Patrick J.#Leahy#VT
# S057
# Patrick J.#Leahy#VT
# S057
# Patrick J.#Leahy#VT
# S057
# Charles E.#Schumer#NY
# S270
# Harold#Rogers#KY
# R000395
# Harold#Rogers#KY
# R000395
# Harold#Rogers#KY
# R000395
# Harold#Rogers#KY
# R000395
# Harold#Rogers#KY
# R000395
# Harold#Rogers#KY
# R000395
# Harold#Rogers#KY
# R000395
# Harold#Rogers#KY
# R000395
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Patty#Murray#WA
# S229
# Harry#Reid#NV
# S198
# Harry#Reid#NV
# S198
# Harry#Reid#NV
# S198
# Harry#Reid#NV
# S198
# Harry#Reid#NV
# S198
# Harry#Reid#NV
# S198
# Harry#Reid#NV
# S198
# Harry#Reid#NV
# S198
# Harry#Reid#NV
# S198
# Michael B.#Enzi#WY
# S254
# Michael B.#Enzi#WY
# S254
# Barbara#Boxer#CA
# S223
# Barbara#Boxer#CA
# S223
# Barbara#Boxer#CA
# S223
# Barbara#Boxer#CA
# S223
# Barbara#Boxer#CA
# S223
# Barbara#Boxer#CA
# S223
# Barbara#Boxer#CA
# S223
# Barbara#Boxer#CA
# S223
# Barbara#Boxer#CA
# S223
# Debbie#Stabenow#MI
# S284
# Debbie#Stabenow#MI
# S284
# Debbie#Stabenow#MI
# S284
# Debbie#Stabenow#MI
# S284
# Lindsey#Graham#SC
# S293
# Debbie#Stabenow#MI
# S284
# Debbie#Stabenow#MI
# S284
# Debbie#Stabenow#MI
# S284
# Debbie#Stabenow#MI
# S284
# Debbie#Stabenow#MI
# S284
# Debbie#Stabenow#MI
# S284
# Debbie#Stabenow#MI
# S284
# Debbie#Stabenow#MI
# S284
# Charles E.#Schumer#NY
# S270
# Charles E.#Schumer#NY
# S270
# Charles E.#Schumer#NY
# S270
# Charles E.#Schumer#NY
# S270
# Charles E.#Schumer#NY
# S270
# Charles E.#Schumer#NY
# S270
# Charles E.#Schumer#NY
# S270
# Charles E.#Schumer#NY
# S270
# Charles E.#Schumer#NY
# S270
# Patty#Murray#WA
# S229
# John#Kline#MN
# K000363
# John#Kline#MN
# K000363
# John#Kline#MN
# K000363
# Doc#Hastings#WA
# H000329
# Harold#Rogers#KY
# R000395
# Harold#Rogers#KY
# R000395
# Diane#Black#TN
# B001273
# Jeff#Merkley#OR
# S322
# Jeff#Merkley#OR
# S322
# Carl#Levin#MI
# S131
# Carl#Levin#MI
# S131
# Harry#Reid#NV
# S198
# Harold#Rogers#KY
# R000395
# Theodore E.#Deutch#FL
# D000610
# Harold#Rogers#KY
# R000395
# Lamar#Smith#TX
# S000636
# Robert#Menendez#NJ
# S306
# Robert#Menendez#NJ
# S306
# Robert#Menendez#NJ
# S306
# Robert#Menendez#NJ
# S306
# Frank D.#Lucas#OK
# L000491
# Jeanne#Shaheen#NH
# S324
# Orrin G.#Hatch#UT
# S118
# Claire#McCaskill#MO
# S312
# Barbara A.#Mikulski#MD
# S182
# Barbara A.#Mikulski#MD
# S182
# Barbara A.#Mikulski#MD
# S182
# Barbara A.#Mikulski#MD
# S182
# Barbara A.#Mikulski#MD
# S182
# Michael G.#Grimm#NY
# G000569
# Harold#Rogers#KY
# R000395
# Joseph R.#Pitts#PA
# P000373
# Lou#Barletta#PA
# B001269
# Bill#Shuster#PA
# S000394
# Harold#Rogers#KY
# R000395
# Virginia#Foxx#NC
# F000450
# Virginia#Foxx#NC
# F000450
# Virginia#Foxx#NC
# F000450
# Charles E.#Schumer#NY
# S270
# Charles E.#Schumer#NY
# S270
# Dave#Camp#MI
# C000071
# Dave#Camp#MI
# C000071
# Dave#Camp#MI
# C000071
# Dave#Camp#MI
# C000071
# Dave#Camp#MI
# C000071
# Harold#Rogers#KY
# R000395
# Harold#Rogers#KY
# R000395
# Barbara A.#Mikulski#MD
# S182
# John#Hoeven#ND
# S344
# Lou#Barletta#PA
# B001269
# Donna M.#Christensen#VI
# C000380
# Dave#Camp#MI
# C000071

# %%
for i in range(1, 114):
    for body in ['house', 'senate']:
        print str(i) + body + ' starting'
        path = 'cleanedcsv/' + str(i) + body + '.csv'
        df = pd.read_csv(path)
        df['sponsor'] = df['sponsor'].apply(reference_leg_id)
        df.to_csv('cleanedcsv2/' + str(i) + body + '.csv', index=False)
        print str(i) + body + ' finished'
# Out:
# 1house starting
# 1house finished
# 1senate starting
# 1senate finished
# 2house starting
# 2house finished
# 2senate starting
# 2senate finished
# 3house starting
# 3house finished
# 3senate starting
# 3senate finished
# 4house starting
# 4house finished
# 4senate starting
# 4senate finished
# 5house starting
# 5house finished
# 5senate starting
# 5senate finished
# 6house starting
# 6house finished
# 6senate starting
# 6senate finished
# 7house starting
# 7house finished
# 7senate starting
# 7senate finished
# 8house starting
# 8house finished
# 8senate starting
# 8senate finished
# 9house starting
# 9house finished
# 9senate starting
# 9senate finished
# 10house starting
# 10house finished
# 10senate starting
# 10senate finished
# 11house starting
# 11house finished
# 11senate starting
# 11senate finished
# 12house starting
# 12house finished
# 12senate starting
# 12senate finished
# 13house starting
# 13house finished
# 13senate starting
# 13senate finished
# 14house starting
# 14house finished
# 14senate starting
# 14senate finished
# 15house starting
# 15house finished
# 15senate starting
# 15senate finished
# 16house starting
# 16house finished
# 16senate starting
# 16senate finished
# 17house starting
# 17house finished
# 17senate starting
# 17senate finished
# 18house starting
# 18house finished
# 18senate starting
# 18senate finished
# 19house starting
# 19house finished
# 19senate starting
# 19senate finished
# 20house starting
# 20house finished
# 20senate starting
# 20senate finished
# 21house starting
# 21house finished
# 21senate starting
# 21senate finished
# 22house starting
# 22house finished
# 22senate starting
# 22senate finished
# 23house starting
# 23house finished
# 23senate starting
# 23senate finished
# 24house starting
# 24house finished
# 24senate starting
# 24senate finished
# 25house starting
# 25house finished
# 25senate starting
# 25senate finished
# 26house starting
# 26house finished
# 26senate starting
# 26senate finished
# 27house starting
# 27house finished
# 27senate starting
# 27senate finished
# 28house starting
# 28house finished
# 28senate starting
# 28senate finished
# 29house starting
# 29house finished
# 29senate starting
# 29senate finished
# 30house starting
# 30house finished
# 30senate starting
# 30senate finished
# 31house starting
# 31house finished
# 31senate starting
# 31senate finished
# 32house starting
# 32house finished
# 32senate starting
# 32senate finished
# 33house starting
# 33house finished
# 33senate starting
# 33senate finished
# 34house starting
# 34house finished
# 34senate starting
# 34senate finished
# 35house starting
# 35house finished
# 35senate starting
# 35senate finished
# 36house starting
# 36house finished
# 36senate starting
# 36senate finished
# 37house starting
# 37house finished
# 37senate starting
# 37senate finished
# 38house starting
# 38house finished
# 38senate starting
# 38senate finished
# 39house starting
# 39house finished
# 39senate starting
# 39senate finished
# 40house starting
# 40house finished
# 40senate starting
# 40senate finished
# 41house starting
# 41house finished
# 41senate starting
# 41senate finished
# 42house starting
# 42house finished
# 42senate starting
# 42senate finished
# 43house starting
# 43house finished
# 43senate starting
# 43senate finished
# 44house starting
# 44house finished
# 44senate starting
# 44senate finished
# 45house starting
# 45house finished
# 45senate starting
# 45senate finished
# 46house starting
# 46house finished
# 46senate starting
# 46senate finished
# 47house starting
# 47house finished
# 47senate starting
# 47senate finished
# 48house starting
# 48house finished
# 48senate starting
# 48senate finished
# 49house starting
# 49house finished
# 49senate starting
# 49senate finished
# 50house starting
# 50house finished
# 50senate starting
# 50senate finished
# 51house starting
# 51house finished
# 51senate starting
# 51senate finished
# 52house starting
# 52house finished
# 52senate starting
# 52senate finished
# 53house starting
# 53house finished
# 53senate starting
# 53senate finished
# 54house starting
# 54house finished
# 54senate starting
# 54senate finished
# 55house starting
# 55house finished
# 55senate starting
# 55senate finished
# 56house starting
# 56house finished
# 56senate starting
# 56senate finished
# 57house starting
# 57house finished
# 57senate starting
# 57senate finished
# 58house starting
# 58house finished
# 58senate starting
# 58senate finished
# 59house starting
# 59house finished
# 59senate starting
# 59senate finished
# 60house starting
# 60house finished
# 60senate starting
# 60senate finished
# 61house starting
# 61house finished
# 61senate starting
# 61senate finished
# 62house starting
# 62house finished
# 62senate starting
# 62senate finished
# 63house starting
# 63house finished
# 63senate starting
# 63senate finished
# 64house starting
# 64house finished
# 64senate starting
# 64senate finished
# 65house starting
# 65house finished
# 65senate starting
# 65senate finished
# 66house starting
# 66house finished
# 66senate starting
# 66senate finished
# 67house starting
# 67house finished
# 67senate starting
# 67senate finished
# 68house starting
# 68house finished
# 68senate starting
# 68senate finished
# 69house starting
# 69house finished
# 69senate starting
# 69senate finished
# 70house starting
# 70house finished
# 70senate starting
# 70senate finished
# 71house starting
# 71house finished
# 71senate starting
# 71senate finished
# 72house starting
# 72house finished
# 72senate starting
# 72senate finished
# 73house starting
# 73house finished
# 73senate starting
# 73senate finished
# 74house starting
# 74house finished
# 74senate starting
# 74senate finished
# 75house starting
# 75house finished
# 75senate starting
# 75senate finished
# 76house starting
# 76house finished
# 76senate starting
# 76senate finished
# 77house starting
# 77house finished
# 77senate starting
# 77senate finished
# 78house starting
# 78house finished
# 78senate starting
# 78senate finished
# 79house starting
# 79house finished
# 79senate starting
# 79senate finished
# 80house starting
# 80house finished
# 80senate starting
# 80senate finished
# 81house starting
# 81house finished
# 81senate starting
# 81senate finished
# 82house starting
# 82house finished
# 82senate starting
# 82senate finished
# 83house starting
# 83house finished
# 83senate starting
# 83senate finished
# 84house starting
# 84house finished
# 84senate starting
# 84senate finished
# 85house starting
# 85house finished
# 85senate starting
# 85senate finished
# 86house starting
# 86house finished
# 86senate starting
# 86senate finished
# 87house starting
# 87house finished
# 87senate starting
# 87senate finished
# 88house starting
# 88house finished
# 88senate starting
# 88senate finished
# 89house starting
# 89house finished
# 89senate starting
# 89senate finished
# 90house starting
# 90house finished
# 90senate starting
# 90senate finished
# 91house starting
# 91house finished
# 91senate starting
# 91senate finished
# 92house starting
# 92house finished
# 92senate starting
# 92senate finished
# 93house starting
# 93house finished
# 93senate starting
# 93senate finished
# 94house starting
# 94house finished
# 94senate starting
# 94senate finished
# 95house starting
# 95house finished
# 95senate starting
# 95senate finished
# 96house starting
# 96house finished
# 96senate starting
# 96senate finished
# 97house starting
# 97house finished
# 97senate starting
# 97senate finished
# 98house starting
# 98house finished
# 98senate starting
# 98senate finished
# 99house starting
# 99house finished
# 99senate starting
# 99senate finished
# 100house starting
# 100house finished
# 100senate starting
# 100senate finished
# 101house starting
# 101house finished
# 101senate starting
# 101senate finished
# 102house starting
# //anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (4,22,33,71,126,151,236,370,409) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-83-999a98dfc49e> in <module>()
#       4         path = 'cleanedcsv/' + str(i) + body + '.csv'
#       5         df = pd.read_csv(path)
# ----> 6         df['sponsor'] = df['sponsor'].apply(reference_leg_id)
#       7         df.to_csv('cleanedcsv2/' + str(i) + body + '.csv', index=False)
#       8         print str(i) + body + ' finished'
#
# //anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2167             values = lib.map_infer(values, lib.Timestamp)
#    2168
# -> 2169         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2170         if len(mapped) and isinstance(mapped[0], Series):
#    2171             from pandas.core.frame import DataFrame
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62578)()
#
# <ipython-input-55-30608f33fed8> in reference_leg_id(namestring)
#      25             lastname = 'Roth'
#      26
# ---> 27         return data.vote_id[data.last_name == lastname][data.state == state].iloc[0]
#      28     else:
#      29         return "unknown"
#
# //anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1225             return self._getitem_tuple(key)
#    1226         else:
# -> 1227             return self._getitem_axis(key, axis=0)
#    1228
#    1229     def _getitem_axis(self, key, axis=0):
#
# //anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1515
#    1516                 # validate the location
# -> 1517                 self._is_valid_integer(key, axis)
#    1518
#    1519             return self._get_loc(key, axis=axis)
#
# //anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _is_valid_integer(self, key, axis)
#    1429         l = len(ax)
#    1430         if key >= l or key < -l:
# -> 1431             raise IndexError("single positional indexer is out-of-bounds")
#    1432         return True
#    1433
#
# IndexError: single positional indexer is out-of-bounds
